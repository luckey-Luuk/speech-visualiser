# %%
import numpy as np

# Data
epochs = np.arange(1,37)
val_loss_9 = [
    3.1873, 2.9779, 2.8184, 2.7302, 2.6800,
    2.6588, 2.6023, 2.5903, 2.5870, 2.5155,
    2.5472, 2.4927, 2.4841, 2.4728, 2.4665, 
    2.4475, None, None, None, None,
    2.4130, 2.4121, 2.4056, 2.4017, 2.3873, 
    2.3901, 2.3774, 2.3793, 2.3864, 2.3856, 
    2.3867, 2.3907, 2.4065, 2.3677, 2.3839, 
    2.3734
]

val_acc_9 = [
    0.1335, 0.1880, 0.2240, 0.2553, 0.2659,
    0.2708, 0.2918, 0.2982, 0.2993, 0.3228,
    0.3158, 0.3290, 0.3358, 0.3315, 0.3381, 
    0.3414, None, None, None, None,
    0.3545, 0.3573, 0.3572, 0.3620, 0.3654, 
    0.3626, 0.3678, 0.3643, 0.3624, 0.3710, 
    0.3554, 0.3617, 0.3713, 0.3710, 0.3677, 
    0.3694
]

val_top5_9 = [
    0.4312, 0.5226, 0.5909, 0.6162, 0.6397,
    0.6399, 0.6573, 0.6612, 0.6598, 0.6760,
    0.6740, 0.6844, 0.6890, 0.6863, 0.6870, 
    0.6925, None, None, None, None,
    0.6982, 0.6992, 0.7018, 0.7043, 0.7046, 
    0.7059, 0.7086, 0.7094, 0.7042, 0.7078, 
    0.7031, 0.7037, 0.7026, 0.7099, 0.7002, 
    0.7069
]

val_loss_5 = [
    3.2594, 2.9283, 2.7708, 2.6877, 2.6827,
    2.5613, 2.5594, 2.5182, 2.5190, 2.4972,
    2.4794, 2.4775, 2.4489, 2.4310, 2.4352,
    2.4454, 2.4061, 2.4191, 2.4041, 2.4105,
    2.3981, 2.3924, 2.3799, 2.4140, 2.3795,
    2.3596, 2.3656, 2.3683, 2.3726, 2.3685,
    2.3776, 2.3767, 2.3639, 2.3634, 2.3799, 
    None
]

val_acc_5 = [
    0.1087, 0.1960, 0.2491, 0.2711, 0.2697,
    0.3117, 0.3159, 0.3219, 0.3156, 0.3245,
    0.3375, 0.3323, 0.3417, 0.3514, 0.3498,
    0.3447, 0.3547, 0.3584, 0.3626, 0.3628,
    0.3667, 0.3585, 0.3645, 0.3548, 0.3674,
    0.3728, 0.3739, 0.3649, 0.3622, 0.3665,
    0.3686, 0.3675, 0.3750, 0.3725, 0.3736, 
    None
]

val_top5_acc_5 = [
    0.3919, 0.5454, 0.6061, 0.6282, 0.6349,
    0.6662, 0.6672, 0.6768, 0.6838, 0.6823,
    0.6826, 0.6835, 0.6919, 0.6985, 0.6992,
    0.6971, 0.7046, 0.7039, 0.7059, 0.7017,
    0.7038, 0.7038, 0.7100, 0.7005, 0.7048,
    0.7120, 0.7142, 0.7128, 0.7121, 0.7102,
    0.7072, 0.7117, 0.7101, 0.7120, 0.7105, 
    None
]

# %%
# Experiment data with masked arrays
import matplotlib.pyplot as plt
import numpy as np

epochs = np.arange(1,37)

# Data from CNN trained on 9 frames
val_loss_9 = np.array([
    3.1873, 2.9779, 2.8184, 2.7302, 2.6800,
    2.6588, 2.6023, 2.5903, 2.5870, 2.5155,
    2.5472, 2.4927, 2.4841, 2.4728, 2.4665, 
    2.4475, None, None, None, None,
    2.4130, 2.4121, 2.4056, 2.4017, 2.3873, 
    2.3901, 2.3774, 2.3793, 2.3864, 2.3856, 
    2.3867, 2.3907, 2.4065, 2.3677, 2.3839, 
    2.3734
]).astype(np.double)
val_loss_9_masked = np.isfinite(val_loss_9)

val_acc_9 = np.array([
    0.1335, 0.1880, 0.2240, 0.2553, 0.2659,
    0.2708, 0.2918, 0.2982, 0.2993, 0.3228,
    0.3158, 0.3290, 0.3358, 0.3315, 0.3381, 
    0.3414, None, None, None, None,
    0.3545, 0.3573, 0.3572, 0.3620, 0.3654, 
    0.3626, 0.3678, 0.3643, 0.3624, 0.3710, 
    0.3554, 0.3617, 0.3713, 0.3710, 0.3677, 
    0.3694
]).astype(np.double)
val_acc_9_masked = np.isfinite(val_acc_9)

val_top5_9 = np.array([
    0.4312, 0.5226, 0.5909, 0.6162, 0.6397,
    0.6399, 0.6573, 0.6612, 0.6598, 0.6760,
    0.6740, 0.6844, 0.6890, 0.6863, 0.6870, 
    0.6925, None, None, None, None,
    0.6982, 0.6992, 0.7018, 0.7043, 0.7046, 
    0.7059, 0.7086, 0.7094, 0.7042, 0.7078, 
    0.7031, 0.7037, 0.7026, 0.7099, 0.7002, 
    0.7069
]).astype(np.double)
val_top5_9_masked = np.isfinite(val_top5_9)


# Data from CNN trained on 5 frames
val_loss_5 = np.array([
    3.2594, 2.9283, 2.7708, 2.6877, 2.6827,
    2.5613, 2.5594, 2.5182, 2.5190, 2.4972,
    2.4794, 2.4775, 2.4489, 2.4310, 2.4352,
    2.4454, 2.4061, 2.4191, 2.4041, 2.4105,
    2.3981, 2.3924, 2.3799, 2.4140, 2.3795,
    2.3596, 2.3656, 2.3683, 2.3726, 2.3685,
    2.3776, 2.3767, 2.3639, 2.3634, 2.3799, 
    None
]).astype(np.double)
val_loss_5_masked = np.isfinite(val_loss_5)

val_acc_5 = np.array([
    0.1087, 0.1960, 0.2491, 0.2711, 0.2697,
    0.3117, 0.3159, 0.3219, 0.3156, 0.3245,
    0.3375, 0.3323, 0.3417, 0.3514, 0.3498,
    0.3447, 0.3547, 0.3584, 0.3626, 0.3628,
    0.3667, 0.3585, 0.3645, 0.3548, 0.3674,
    0.3728, 0.3739, 0.3649, 0.3622, 0.3665,
    0.3686, 0.3675, 0.3750, 0.3725, 0.3736, 
    None
]).astype(np.double)
val_acc_5_masked = np.isfinite(val_acc_5)

val_top5_5 = np.array([
    0.3919, 0.5454, 0.6061, 0.6282, 0.6349,
    0.6662, 0.6672, 0.6768, 0.6838, 0.6823,
    0.6826, 0.6835, 0.6919, 0.6985, 0.6992,
    0.6971, 0.7046, 0.7039, 0.7059, 0.7017,
    0.7038, 0.7038, 0.7100, 0.7005, 0.7048,
    0.7120, 0.7142, 0.7128, 0.7121, 0.7102,
    0.7072, 0.7117, 0.7101, 0.7120, 0.7105, 
    None
]).astype(np.double)
val_top5_5_masked = np.isfinite(val_top5_5)

# %%
# Plot for confidence interval

# Style
plt.style.use("seaborn-v0_8")

fig, ax1 = plt.subplots(figsize=(12,6))


# Highlight best points
# best_loss_idx = np.where(val_loss_9 = min(val_loss_9))

# Left y-axis for loss
color = "tab:red"
ax1.set_xlabel("Epoch", fontsize=14)
ax1.set_ylabel("Validation Loss", fontsize=14)
ax1.plot(epochs[val_loss_9_masked], val_loss_9[val_loss_9_masked], "o-", color=color, label="Val loss 9 frames")
ax1.plot(epochs[val_loss_5_masked], val_loss_5[val_loss_5_masked], "o-", color="tab:purple", label="Val loss 5 frames")
ax1.tick_params(axis="y")
ax1.grid(alpha=0.3)
ax1.set_xlim(1, None)
# ax1.set_ylim(0, None)

# Legends
lines1, labels1 = ax1.get_legend_handles_labels()
ax1.legend(lines1, labels1, loc="upper right", fontsize=12)


# Highlight best points
best_loss_idx_9 = np.where(val_loss_9 == min(val_loss_9))[0][0]
print(best_loss_idx_9)
best_loss_idx_5 = np.where(val_loss_5 == min(val_loss_5))[0][0]

plt.scatter(epochs[best_loss_idx_9], val_loss_9[best_loss_idx_9], color="red", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Loss\n{val_loss_9[best_loss_idx_9]:.3f}",
            (epochs[best_loss_idx_9], val_loss_9[best_loss_idx_9]),
            xytext=(epochs[best_loss_idx_9]+1, val_loss_9[best_loss_idx_9]+0.15),
            arrowprops=dict(arrowstyle="->", color="black", lw=1.0))


plt.scatter(epochs[best_loss_idx_5], val_loss_5[best_loss_idx_5], color="purple", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Loss\n{val_loss_5[best_loss_idx_5]:.3f}",
            (epochs[best_loss_idx_5], val_loss_5[best_loss_idx_5]),
            xytext=(epochs[best_loss_idx_5]+1, val_loss_5[best_loss_idx_5]+0.15),
            arrowprops=dict(arrowstyle="->", color="black", lw=1.0))

plt.title("CNN Validation loss", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# 33

# %%
# Plot for accuracy

# Style
plt.style.use("seaborn-v0_8")

fig, ax2 = plt.subplots(figsize=(12,6))

# Right y-axis for accuracy
ax2.set_ylabel("Accuracy", fontsize=14)
ax2.set_xlabel("Epoch", fontsize=14)
ax2.tick_params(axis="y")
ax2.set_ylim(0, 1.0)  # accuracy scale from 0 to 1

# accuracy top 1
ax2.plot(epochs[val_acc_9_masked], val_acc_9[val_acc_9_masked], "o-", color="tab:blue", label="Val accuracy 9 frames")
ax2.plot(epochs[val_acc_5_masked], val_acc_5[val_acc_5_masked], "o-", color="darkblue", label="Val accuracy 5 frames")
# accuracy top 5
ax2.plot(epochs[val_top5_9_masked], val_top5_9[val_top5_9_masked], "o-", color="tab:green", label="Val top-5 Acc 9 frames")
ax2.plot(epochs[val_top5_5_masked], val_top5_5[val_top5_5_masked], "o-", color="darkgreen", label="Val top-5 Acc 5 frames")

# Legends
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines2, labels2, loc="upper left", fontsize=12)

# Highlight best poitns
best_acc_idx_9 = np.where(val_acc_9 == max(val_acc_9))[0][0]
best_5_idx_9 = np.where(val_top5_9 == max(val_top5_9))[0][0]
best_acc_idx_5 = np.where(val_acc_5 == max(val_acc_5))[0][0]
best_5_idx_5 = np.where(val_top5_5 == max(val_top5_5))[0][0]

plt.scatter(epochs[best_acc_idx_9], val_acc_9[best_acc_idx_9], color="tab:blue", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Acc\n{val_acc_9[best_acc_idx_9]:.3f}",  
             (epochs[best_acc_idx_9], val_acc_9[best_acc_idx_9]),
             xytext=(epochs[best_acc_idx_9]+1, val_acc_9[best_acc_idx_9]+0.06),
             arrowprops=dict(arrowstyle="->", color="tab:blue", lw=1.0), color="tab:blue")


plt.scatter(epochs[best_5_idx_9], val_top5_9[best_5_idx_9], color="tab:green", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Acc\n{val_top5_9[best_5_idx_9]:.3f}",
             (epochs[best_5_idx_9], val_top5_9[best_5_idx_9]),
             xytext=(epochs[best_5_idx_9]+1,  val_top5_9[best_5_idx_9]+0.06),
             arrowprops=dict(arrowstyle="->", color="tab:green", lw=1.0), color="tab:green")


plt.scatter(epochs[best_acc_idx_5], val_acc_9[best_acc_idx_5], color="darkblue", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Acc\n{val_acc_5[best_acc_idx_5]:.3f}",
             (epochs[best_acc_idx_5], val_acc_9[best_acc_idx_5]),
             xytext=(epochs[best_acc_idx_5]+1, val_acc_9[best_acc_idx_5]+0.16),
             arrowprops=dict(arrowstyle="->", color="darkblue", lw=1.0), color="darkblue")


plt.scatter(epochs[best_5_idx_9], val_top5_9[best_5_idx_9], color="darkgreen", s=100, edgecolors="black", zorder=5)
plt.annotate(f"Best Acc\n{val_top5_5[best_5_idx_5]:.3f}",
             (epochs[best_5_idx_5], val_top5_9[best_5_idx_5]),
             xytext=(epochs[best_5_idx_5]+1,  val_top5_9[best_5_idx_5]+0.06),
             arrowprops=dict(arrowstyle="->", color="darkgreen", lw=1.0), color="darkgreen")

# Title
plt.title("CNN Validation Accuracy", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
